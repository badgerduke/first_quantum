# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
from math import pi
# %matplotlib inline

# %% [markdown]
# # PAULI-Z

# %%
# Apply Z Gate once - qubit initialized to zero - should remain to zero and have
# relative phase change

circuit = QuantumCircuit(1)  # circuit with one qubit 
circuit.z(0) # apply Pauli Y Gate to qubit
print(circuit)
# Out:
#    ┌───┐
# q: ┤ Z ├
#    └───┘

# %%
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')  # create simulator returning state vector of qubit
result = execute(circuit, backend = simulator).result()  # only single shot needed
statevector = result.get_statevector()
print(statevector)  
# j = imaginary unit (i)  so [1, 0] = |0>
array_to_latex(statevector, prefix="\\text{statevector = }\n")
# Out:
# Statevector([ 1.+0.j, -0.+0.j],
#             dims=(2,))
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(statevector)  # print bloch sphere

# %%
# Apply Y Gate once - qubit in superposition - no Pauli Z gate yet


circuit = QuantumCircuit(2)  # circuit with two qubits
circuit.ry(pi/4, [0,1]) # put qubits in superposition
print(circuit)
# Out:
#      ┌─────────┐
# q_0: ┤ Ry(π/4) ├
#      ├─────────┤
# q_1: ┤ Ry(π/4) ├
#      └─────────┘

# %%
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')  # create simulator returning state vector of qubit
result = execute(circuit, backend = simulator).result()  # only single shot needed
statevector = result.get_statevector()
print(statevector)  
# j = imaginary unit (i)  so [1, 0] = |0>
array_to_latex(statevector, prefix="\\text{statevector = }\n")
# Out:
# Statevector([0.85355339+0.j, 0.35355339+0.j, 0.35355339+0.j,
#              0.14644661+0.j],
#             dims=(2, 2))
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# 0.8535533906 & \frac{\sqrt{2}}{4} & \frac{\sqrt{2}}{4} & 0.1464466094  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(statevector)  # print bloch sphere

# %%
# Apply Y Gate once - qubit in superposition - apply Pauli Z gate to second qubit


circuit = QuantumCircuit(2)  # circuit with two qubits
circuit.ry(pi/4, [0,1]) # put qubits in superposition
circuit.z(1)
print(circuit)
# Out:
#      ┌─────────┐
# q_0: ┤ Ry(π/4) ├─────
#      ├─────────┤┌───┐
# q_1: ┤ Ry(π/4) ├┤ Z ├
#      └─────────┘└───┘

# %%
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')  # create simulator returning state vector of qubit
result = execute(circuit, backend = simulator).result()  # only single shot needed
statevector = result.get_statevector()
print(statevector)  
# j = imaginary unit (i)  so [1, 0] = |0>
array_to_latex(statevector, prefix="\\text{statevector = }\n")
# Out:
# Statevector([ 0.85355339+0.j,  0.35355339+0.j, -0.35355339+0.j,
#              -0.14644661+0.j],
#             dims=(2, 2))
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# 0.8535533906 & \frac{\sqrt{2}}{4} & - \frac{\sqrt{2}}{4} & -0.1464466094  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(statevector)  # print bloch sphere
